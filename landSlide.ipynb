# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Đọc dữ liệu

# %%
landSlide = pd.read_excel(r"D:\huhu\UngDung\BTS2\CSDL_YenBai_CoTruot.xlsx")

# %%
# landSlide.head()
landSlide.info()
# landSlide.describe()
# landSlide.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pointid       2089 non-null   int64
#  1   ma_cu         2089 non-null   int64
#  2   ma_moi        2089 non-null   int64
#  3   slope         2089 non-null   int64
#  4   elevation     2089 non-null   int64
#  5   thachhoc      2089 non-null   int64
#  6   dis_dutgay    2089 non-null   int64
#  7   dis_thachhoc  2089 non-null   int64
#  8   dis_river     2089 non-null   int64
#  9   dis_mainroad  2089 non-null   int64
#  10  dis_road      2089 non-null   int64
#  11  dis_dancu     2089 non-null   int64
#  12  output        2089 non-null   int64
# dtypes: int64(13)
# memory usage: 212.3 KB

# %%
noLandSlide = pd.read_excel(r"D:\huhu\UngDung\BTS2\CSDL_YenBai_KoTruot.xlsx")

# %%
noLandSlide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240817 entries, 0 to 240816
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   pointid       240817 non-null  int64
#  1   ma_cu         240817 non-null  int64
#  2   ma_moi        240817 non-null  int64
#  3   slope         240817 non-null  int64
#  4   elevation     240817 non-null  int64
#  5   thachhoc      240817 non-null  int64
#  6   dis_dutgay    240817 non-null  int64
#  7   dis_thachhoc  240817 non-null  int64
#  8   dis_river     240817 non-null  int64
#  9   dis_mainroad  240817 non-null  int64
#  10  dis_road      240817 non-null  int64
#  11  dis_dancu     240817 non-null  int64
#  12  output        240817 non-null  int64
# dtypes: int64(13)
# memory usage: 23.9 MB

# %% [markdown]
# * Tiền xử lý dữ liệu

# %%
columns_to_check = ['slope', 'elevation', 'thachhoc', 'dis_dutgay', 'dis_thachhoc', 'dis_river', 'dis_mainroad', 'dis_road', 'dis_dancu']

# %%
noLandSlide_sampled = noLandSlide.sample(n=len(landSlide)*2, random_state=42)

# %% [markdown]
# * Đánh giá phân phối từng thuộc tính riêng lẻ giữa tập lấy mẫu và tập ban đầu

# %%
from scipy.stats import ks_2samp

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['slope'], noLandSlide_sampled['slope'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.008217917014119752
# p-value: 0.942131219417748
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['elevation'], noLandSlide_sampled['elevation'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.004591242951111241
# p-value: 0.9999930254285724
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['thachhoc'], noLandSlide_sampled['thachhoc'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.010257869118841856
# p-value: 0.7764220399307524
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['dis_dutgay'], noLandSlide_sampled['dis_dutgay'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.006606111901504397
# p-value: 0.9934496214961532
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['dis_thachhoc'], noLandSlide_sampled['dis_thachhoc'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.0023224971356831103
# p-value: 1.0
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['dis_river'], noLandSlide_sampled['dis_river'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.017308333616579352
# p-value: 0.1686785687954392
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['dis_mainroad'], noLandSlide_sampled['dis_mainroad'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.004276598797742448
# p-value: 0.9999990991104182
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['dis_road'], noLandSlide_sampled['dis_road'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.014454080964009242
# p-value: 0.3540902859178485
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %%
ks_statistic, p_value = ks_2samp(noLandSlide['dis_dancu'], noLandSlide_sampled['dis_dancu'])

print(f'KS Statistic: {ks_statistic}')
print(f'p-value: {p_value}')

# Đưa ra kết luận dựa trên p-value
if p_value < 0.05:
    print("Hai mẫu có phân phối khác nhau với mức ý nghĩa 5%.")
else:
    print("Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.")
# Out:
# KS Statistic: 0.004192383327099591
# p-value: 0.9999995194934339
# Không có bằng chứng đủ để kết luận hai mẫu có phân phối khác nhau.

# %% [markdown]
# * Đánh giá sự tương quan giữa các thuộc tính của 2 tập dữ liệu

# %% [markdown]
# Bản đồ nhiệt Dataframe noLandSlide

# %%
correlation_matrix = noLandSlide[columns_to_check].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Bản đồ nhiệt tập lấy mẫu của Dataframe noLandSlide

# %%
correlation_matrix = noLandSlide_sampled[columns_to_check].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
combined_df = pd.concat([landSlide, noLandSlide_sampled], ignore_index=True)
shuffled_df = combined_df.sample(frac=1, random_state=42).reset_index(drop=True)
shuffled_df.to_excel("dataset.xlsx", index=False)

# %% [markdown]
# * Random Forest

# %%
data = pd.read_excel(r"D:\huhu\UngDung\BTS2\dataset.xlsx")

# %%
data.head()
# Out:
#    pointid    ma_cu   ma_moi  slope  elevation  thachhoc  dis_dutgay  \
# 0  1163862  1163862  1163862      4          2         2           1
# 1  1064681  1064681  1064681      2          2         2           1
# 2  1202164  1202164  1202164      4          2         4           0
# 3  1210551  1210551  1210551      4          4         4           2
# 4  1024569  1024569  1024569      4          4         4           0
#
#    dis_thachhoc  dis_river  dis_mainroad  dis_road  dis_dancu  output
# 0             2          2             0         4          1       0
# 1             4          0             0         0          0       0
# 2             1          0             0         0          0       0
# 3             0          4             0         4          2       0
# 4             0          1             0         1          0       0

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X = data[columns_to_check]
y = data['output']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = RandomForestClassifier(n_estimators=200, random_state=42, max_depth=5)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.89792663476874
# Confusion Matrix:
#  [[1200   67]
#  [ 125  489]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      1267
#            1       0.88      0.80      0.84       614
#
#     accuracy                           0.90      1881
#    macro avg       0.89      0.87      0.88      1881
# weighted avg       0.90      0.90      0.90      1881
